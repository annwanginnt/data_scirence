# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mei88\OneDrive\桌面\MMAI-5000N AI\group project\neighbourhood _t.csv")

# %%
df
# Out:
#                    Characteristic  Neighbourhood Number  \
# 0                 City of Toronto                   NaN
# 1                 Agincourt North                 129.0
# 2    Agincourt South-Malvern West                 128.0
# 3                       Alderwood                  20.0
# 4                           Annex                  95.0
# ..                            ...                   ...
# 136                      Wychwood                  94.0
# 137                Yonge-Eglinton                 100.0
# 138                Yonge-St.Clair                  97.0
# 139       York University Heights                  27.0
# 140            Yorkdale-Glen Park                  31.0
#
#        TSNS2020 Designation Population, 2016 Population, 2011  \
# 0                       NaN        2,731,571        2,615,060
# 1            No Designation           29,113           30,279
# 2            No Designation           23,757           21,988
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Columns: 2384 entries, Characteristic to       External migrants.1
# dtypes: float64(50), int64(1049), object(1285)
# memory usage: 2.6+ MB

# %%
#remove unnecesary columns
df = df.drop('TSNS2020 Designation', axis=1)

# %%
df.describe(include='all')
# Out:
#          Characteristic  Neighbourhood Number Population, 2016  \
# count               141              140.0000              141
# unique              141                   NaN              141
# top     City of Toronto                   NaN        2,731,571
# freq                  1                   NaN                1
# mean                NaN               70.5000              NaN
# std                 NaN               40.5586              NaN
# min                 NaN                1.0000              NaN
# 25%                 NaN               35.7500              NaN
# 50%                 NaN               70.5000              NaN
# 75%                 NaN              105.2500              NaN
# max                 NaN              140.0000              NaN
#
#        Population, 2011 Population Change 2011-2016 Total private dwellings  \
# count               141                         141                     141
# ...

# %%
#since city of Toronto include all the neighbourhoods, so we consider it as a outlier, remove it. 
df = df.drop(0)

# %%
# check all columns, we realzied 'neighbourhood number' should be str. and other column's values should be int
df.describe(include='all')
# Out:
#          Characteristic  Neighbourhood Number Population, 2016  \
# count               140              140.0000              140
# unique              140                   NaN              140
# top     Agincourt North                   NaN           29,113
# freq                  1                   NaN                1
# mean                NaN               70.5000              NaN
# std                 NaN               40.5586              NaN
# min                 NaN                1.0000              NaN
# 25%                 NaN               35.7500              NaN
# 50%                 NaN               70.5000              NaN
# 75%                 NaN              105.2500              NaN
# max                 NaN              140.0000              NaN
#
#        Population, 2011 Population Change 2011-2016 Total private dwellings  \
# count               140                         140                     140
# ...

# %%
df.dtypes
# Out:
# Characteristic                         object
# Neighbourhood Number                  float64
# Population, 2016                       object
# Population, 2011                       object
# Population Change 2011-2016            object
#                                        ...
#   Movers.1                             object
#     Non-migrants.1                     object
#     Migrants.1                         object
#         Interprovincial migrants.1     object
#       External migrants.1              object
# Length: 2383, dtype: object

# %%
# neighbourhood number should be treated as categorical number
df['Neighbourhood Number']= df['Neighbourhood Number'].astype(str).str.split('.').str[0]

# %%
df
# Out:
#                    Characteristic Neighbourhood Number Population, 2016  \
# 1                 Agincourt North                  129           29,113
# 2    Agincourt South-Malvern West                  128           23,757
# 3                       Alderwood                   20           12,054
# 4                           Annex                   95           30,526
# 5               Banbury-Don Mills                   42           27,695
# ..                            ...                  ...              ...
# 136                      Wychwood                   94           14,349
# 137                Yonge-Eglinton                  100           11,817
# 138                Yonge-St.Clair                   97           12,528
# 139       York University Heights                   27           27,593
# 140            Yorkdale-Glen Park                   31           14,804
#
#     Population, 2011 Population Change 2011-2016 Total private dwellings  \
# ...

# %%
#df['Population, 2016'] = df['Population, 2016'].astype(float)

# %%
columns = df.columns[2:]
df[columns] = df[columns].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[228], line 2
#       1 columns = df.columns[2:]
# ----> 2 df[columns] = df[columns].astype(float)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
df
# Out:
#                    Characteristic Neighbourhood Number  Population, 2016  \
# 1                 Agincourt North                  129               NaN
# 2    Agincourt South-Malvern West                  128               NaN
# 3                       Alderwood                   20               NaN
# 4                           Annex                   95               NaN
# 5               Banbury-Don Mills                   42               NaN
# ..                            ...                  ...               ...
# 136                      Wychwood                   94               NaN
# 137                Yonge-Eglinton                  100               NaN
# 138                Yonge-St.Clair                   97               NaN
# 139       York University Heights                   27               NaN
# 140            Yorkdale-Glen Park                   31               NaN
#
#      Population, 2011  Population Change 2011-2016  Total private dwellings  \
# ...

# %%
df.dtypes
# Out:
# Characteristic                         object
# Neighbourhood Number                   object
# Population, 2016                      float64
# Population, 2011                      float64
# Population Change 2011-2016           float64
#                                        ...
#   Movers.1                            float64
#     Non-migrants.1                    float64
#     Migrants.1                        float64
#         Interprovincial migrants.1    float64
#       External migrants.1             float64
# Length: 2383, dtype: object

# %%
df
# Out:
#                    Characteristic Neighbourhood Number  Population, 2016  \
# 1                 Agincourt North                  129               NaN
# 2    Agincourt South-Malvern West                  128               NaN
# 3                       Alderwood                   20               NaN
# 4                           Annex                   95               NaN
# 5               Banbury-Don Mills                   42               NaN
# ..                            ...                  ...               ...
# 136                      Wychwood                   94               NaN
# 137                Yonge-Eglinton                  100               NaN
# 138                Yonge-St.Clair                   97               NaN
# 139       York University Heights                   27               NaN
# 140            Yorkdale-Glen Park                   31               NaN
#
#      Population, 2011  Population Change 2011-2016  Total private dwellings  \
# ...
